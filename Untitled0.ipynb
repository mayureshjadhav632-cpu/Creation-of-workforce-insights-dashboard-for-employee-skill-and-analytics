# %% [markdown]
# <a href="https://colab.research.google.com/github/mayureshjadhav632-cpu/Creation-of-workforce-insights-dashboard-for-employee-skill-and-analytics/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
Create a complete working prototype for the project titled:

"AI-Powered Workforce Analytics & Talent Intelligence Dashboard"

Project objective:
Build an interactive web-based HR analytics dashboard that analyzes employee/workforce data and provides actionable insights using AI, predictive analytics, and natural language querying.

Development environment:

- The project will initially be developed and tested in Google Colab.
- Use Python.
- Use Pandas and NumPy for data processing.
- Use Plotly for interactive visualizations.
- Use Streamlit for the dashboard interface.
- Use Scikit-learn for machine learning/predictive analytics.
- Use a suitable LLM approach for natural-language workforce insights.
- Keep the implementation beginner-friendly and modular.

Create a synthetic employee dataset if no real HR dataset is available. The dataset should contain fields such as:

- Employee ID
- Age
- Gender
- Department
- Job Role
- Education
- Experience
- Salary
- Performance Score
- Job Satisfaction
- Work-Life Balance
- Training Hours
- Skills
- Promotion History
- Years at Company
- Attendance
- Engagement Score
- Attrition
- Recruitment Source

Dashboard requirements:

1. Executive Overview
   Display:

- Total employees
- Average performance
- Average engagement
- Attrition rate
- Average salary
- Training participation
- Department-wise employee count

2. Workforce Analytics
   Create interactive charts for:

- Employees by department
- Employees by job role
- Gender distribution
- Age distribution
- Salary distribution
- Experience distribution
- Performance trends

3. Employee Engagement
   Analyze:

- Job satisfaction
- Engagement score
- Work-life balance
- Training participation
- Relationship between engagement and performance

4. Attrition Prediction
   Build a machine-learning model that predicts employee attrition risk.

- Prepare the data
- Encode categorical variables
- Train a suitable classification model
- Evaluate the model using accuracy, precision, recall and F1-score
- Display high-risk employee categories
- Show the major factors associated with attrition

Do NOT make decisions about real employees based solely on the model. Clearly label predictions as risk indicators rather than definite outcomes.

5. Talent & Skills Intelligence
   Analyze employee skills and training.
   Show:

- Most common skills
- Skill gaps
- Department-wise skills
- Training hours
- Employees needing development opportunities
- Possible career-development recommendations

6. Diversity & Inclusion Analytics
   Show aggregated organizational metrics such as:

- Gender distribution
- Department-wise representation
- Role-wise representation
- Diversity trends

Avoid making hiring, promotion, or termination decisions automatically based on protected characteristics.

7. Recruitment Analytics
   Analyze:

- Recruitment source
- Number of hires
- Attrition by recruitment source
- Performance by recruitment source
- Recruitment effectiveness

8. Workforce Planning
   Provide AI-assisted recommendations based on:

- Employee count
- Attrition trends
- Skill gaps
- Department growth
- Performance
- Training requirements

9. Natural Language AI Assistant
   Add a conversational interface where a user can ask questions such as:

- "Which department has the highest attrition?"
- "What are the most common employee skills?"
- "Which areas have the biggest skill gaps?"
- "What factors are associated with employee attrition?"
- "Which departments have low engagement?"
- "What workforce development actions should HR consider?"

The assistant should answer using the available dataset and calculated analytics. Do not invent statistics that are not present in the data.

10. RAG Architecture
    Create a simple RAG-ready architecture where HR policy documents or organizational documents can later be uploaded and indexed.
    Explain how:

- Documents are loaded
- Text is split into chunks
- Embeddings are generated
- Relevant chunks are retrieved
- The LLM uses retrieved information to answer questions

If implementing a complete external LLM/RAG system is not possible in Colab without API keys, create a working prototype/mock implementation and clearly mark where the API key and RAG components should later be connected.

11. Agentic AI Workflow
    Design the architecture for multiple AI agents:

- Workforce Analytics Agent
- Attrition Risk Agent
- Skills Intelligence Agent
- Recruitment Analytics Agent
- Workforce Planning Agent

The agents should analyze specific aspects of workforce data and provide recommendations that can be combined into an executive summary.

12. Dashboard UI
    Create a professional dashboard with:

- Sidebar navigation
- KPI cards
- Interactive Plotly charts
- Filters for department, gender, job role and other relevant fields
- Tables for analytical results
- AI insight section
- Workforce recommendations section

13. Code requirements
    Provide the implementation in clearly separated Google Colab cells:
    Cell 1: Install/import libraries
    Cell 2: Generate/load dataset
    Cell 3: Data cleaning and preprocessing
    Cell 4: Exploratory analysis
    Cell 5: Attrition prediction model
    Cell 6: Skills analytics
    Cell 7: Recruitment analytics
    Cell 8: Workforce planning analytics
    Cell 9: AI insight generation
    Cell 10: RAG architecture/prototype
    Cell 11: Streamlit dashboard
    Cell 12: Instructions for running the dashboard in Google Colab

Make the code executable and explain what each cell does.

Also provide:

1. Project architecture
2. Technology stack
3. Data-flow explanation
4. Machine-learning methodology
5. RAG methodology
6. Agentic AI workflow
7. Expected dashboard output
8. Future enhancements

Start by creating a complete minimum viable prototype first. Avoid unnecessary complexity and make sure the basic dashboard and analytics work before adding advanced AI features.
'''
# Out:
# '\nCreate a complete working prototype for the project titled:\n\n"AI-Powered Workforce Analytics & Talent Intelligence Dashboard"\n\nProject objective:\nBuild an interactive web-based HR analytics dashboard that analyzes employee/workforce data and provides actionable insights using AI, predictive analytics, and natural language querying.\n\nDevelopment environment:\n\n- The project will initially be developed and tested in Google Colab.\n- Use Python.\n- Use Pandas and NumPy for data processing.\n- Use Plotly for interactive visualizations.\n- Use Streamlit for the dashboard interface.\n- Use Scikit-learn for machine learning/predictive analytics.\n- Use a suitable LLM approach for natural-language workforce insights.\n- Keep the implementation beginner-friendly and modular.\n\nCreate a synthetic employee dataset if no real HR dataset is available. The dataset should contain fields such as:\n\n- Employee ID\n- Age\n- Gender\n- Department\n- Job Role\n- Education\n- Experience\n- Sa
# ...

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Creating a synthetic HR employee dataset

# %%
num_employees = 1000

data = {
    'Employee_ID': range(1, num_employees + 1),
    'Age': np.random.randint(22, 60, num_employees),
    'Gender': np.random.choice(['Male', 'Female', 'Other'], num_employees, p=[0.48, 0.48, 0.04]),
    'Department': np.random.choice(['HR', 'Sales', 'Marketing', 'Engineering', 'Finance', 'Operations'], num_employees),
    'Job_Role': np.random.choice(['Analyst', 'Manager', 'Engineer', 'Specialist', 'Director'], num_employees),
    'Education': np.random.choice(['High School', 'Bachelors', 'Masters', 'PhD'], num_employees, p=[0.1, 0.5, 0.3, 0.1]),
    'Experience': np.random.randint(0, 30, num_employees),
    'Salary': np.random.randint(40000, 150000, num_employees),
    'Performance_Score': np.random.randint(1, 5, num_employees),
    'Job_Satisfaction': np.random.randint(1, 5, num_employees),
    'Work_Life_Balance': np.random.randint(1, 5, num_employees),
    'Training_Hours': np.random.randint(10, 100, num_employees),
    'Skills': [np.random.choice(['Python', 'SQL', 'Excel', 'Communication', 'Leadership', 'Project Management', 'Data Analysis', 'Machine Learning', 'Cloud Computing'], np.random.randint(1, 5), replace=False) for _ in range(num_employees)],
    'Years_at_Company': np.random.randint(0, 20, num_employees),
    'Attendance': np.random.randint(85, 100, num_employees),
    'Engagement_Score': np.random.randint(1, 5, num_employees),
    'Attrition': np.random.choice([0, 1], num_employees, p=[0.85, 0.15]), # 0 = No, 1 = Yes
    'Recruitment_Source': np.random.choice(['Referral', 'LinkedIn', 'Career Fair', 'Website'], num_employees),
    'Diversity_Category': np.random.choice(['Minority', 'Majority'], num_employees, p=[0.3, 0.7]), # New feature
    'Skill_Level': np.random.choice(['Beginner', 'Intermediate', 'Advanced'], num_employees, p=[0.3, 0.5, 0.2]) # New feature
}

df = pd.DataFrame(data)

# %%
import numpy as np
import pandas as pd

num_employees = 1000

data = {
    'Employee_ID': range(1, num_employees + 1),
    'Age': np.random.randint(22, 60, num_employees),
    'Gender': np.random.choice(['Male', 'Female', 'Other'], num_employees, p=[0.48, 0.48, 0.04]),
    'Department': np.random.choice(['HR', 'Sales', 'Marketing', 'Engineering', 'Finance', 'Operations'], num_employees),
    'Job_Role': np.random.choice(['Analyst', 'Manager', 'Engineer', 'Specialist', 'Director'], num_employees),
    'Education': np.random.choice(['High School', 'Bachelors', 'Masters', 'PhD'], num_employees, p=[0.1, 0.5, 0.3, 0.1]),
    'Experience': np.random.randint(0, 30, num_employees),
    'Salary': np.random.randint(40000, 150000, num_employees),
    'Performance_Score': np.random.randint(1, 5, num_employees),
    'Job_Satisfaction': np.random.randint(1, 5, num_employees),
    'Work_Life_Balance': np.random.randint(1, 5, num_employees),
    'Training_Hours': np.random.randint(10, 100, num_employees),
    'Skills': [
        np.random.choice(
            ['Python', 'SQL', 'Excel', 'Communication', 'Leadership',
             'Project Management', 'Data Analysis', 'Machine Learning',
             'Cloud Computing'],
            np.random.randint(1, 5),
            replace=False
        )
        for _ in range(num_employees)
    ],
    'Years_at_Company': np.random.randint(0, 20, num_employees),
    'Attendance': np.random.randint(85, 100, num_employees),
    'Engagement_Score': np.random.randint(1, 5, num_employees),
    'Attrition': np.random.choice([0, 1], num_employees, p=[0.85, 0.15]),
    'Recruitment_Source': np.random.choice(['Referral', 'LinkedIn', 'Career Fair', 'Website'], num_employees),
    'Diversity_Category': np.random.choice(['Minority', 'Majority'], num_employees, p=[0.3, 0.7]),
    'Skill_Level': np.random.choice(['Beginner', 'Intermediate', 'Advanced'], num_employees, p=[0.3, 0.5, 0.2])
}

df = pd.DataFrame(data)

print("Dataset created successfully!")
print("Shape:", df.shape)
# Out:
# Dataset created successfully!
# Shape: (1000, 20)

# %%
print(df.columns.tolist())
# Out:
# ['Employee_ID', 'Age', 'Gender', 'Department', 'Job_Role', 'Education', 'Experience', 'Salary', 'Performance_Score', 'Job_Satisfaction', 'Work_Life_Balance', 'Training_Hours', 'Skills', 'Years_at_Company', 'Attendance', 'Engagement_Score', 'Attrition', 'Recruitment_Source', 'Diversity_Category', 'Skill_Level']

# %%
workforce_summary = {
    "total_employees": len(df),
    "average_age": round(df["Age"].mean(), 2),
    "average_salary": round(df["Salary"].mean(), 2),
    "average_performance": round(df["Performance_Score"].mean(), 2),
    "average_job_satisfaction": round(df["Job_Satisfaction"].mean(), 2),
    "average_engagement": round(df["Engagement_Score"].mean(), 2),
    "attrition_count": int(df["Attrition"].sum()),
    "attrition_rate": round(df["Attrition"].mean() * 100, 2),
    "department_counts": df["Department"].value_counts().to_dict()
}

print(workforce_summary)
# Out:
# {'total_employees': 1000, 'average_age': np.float64(40.66), 'average_salary': np.float64(96817.11), 'average_performance': np.float64(2.49), 'average_job_satisfaction': np.float64(2.5), 'average_engagement': np.float64(2.53), 'attrition_count': 159, 'attrition_rate': np.float64(15.9), 'department_counts': {'Marketing': 194, 'Sales': 176, 'Finance': 172, 'HR': 165, 'Operations': 156, 'Engineering': 137}}

# %% [markdown]
# ### Display the first 10 rows of the dataset

# %%
print("Employees:", len(df))
print("Average Age:", round(df["Age"].mean(), 2))
print("Average Salary:", round(df["Salary"].mean(), 2))
print("Attrition Rate:", round(df["Attrition"].mean() * 100, 2), "%")
print("Average Engagement:", round(df["Engagement_Score"].mean(), 2))
print("Average Satisfaction:", round(df["Job_Satisfaction"].mean(), 2))

print("\nEmployees by Department:")
print(df["Department"].value_counts())
# Out:
# Employees: 1000
# Average Age: 40.66
# Average Salary: 96817.11
# Attrition Rate: 15.9 %
# Average Engagement: 2.53
# Average Satisfaction: 2.5
#
# Employees by Department:
# Department
# Marketing      194
# Sales          176
# Finance        172
# HR             165
# Operations     156
# Engineering    137
# Name: count, dtype: int64

# %%
prompt = f"""
You are an AI Workforce Analytics Assistant.

Here are the workforce analytics results:

- Total employees: {len(df)}
- Average age: {df["Age"].mean():.2f}
- Average salary: {df["Salary"].mean():.2f}
- Attrition rate: {df["Attrition"].mean() * 100:.2f}%
- Average engagement score: {df["Engagement_Score"].mean():.2f}
- Average job satisfaction: {df["Job_Satisfaction"].mean():.2f}

Department employee counts:
{df["Department"].value_counts().to_dict()}

Analyze this information and provide:
1. A short workforce overview.
2. The most important insight.
3. An observation about attrition.
4. Two practical recommendations for HR.

Use only the data provided above.
"""

messages = [
    {
        "role": "user",
        "content": prompt
    }
]

result = pipe(messages, max_new_tokens=300)

print(result[0]["generated_text"][-1]["content"])
# Out:
# [transformers] Both `max_new_tokens` (=300) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ### 1. Short Workforce Overview
#
# The organization has approximately 1000 employees across various departments with an average age of 40.66 years and an average salary of $96,817.11 per year. The company experiences a high attrition rate of 15.90%, indicating that many employees leave each year. This is reflected in their average engagement scores (2.53) and job satisfaction levels (2.50).
#
# ### 2. Most Important Insight
#
# One of the most significant insights from these numbers is the high attrition rate of 15.90%. Given this trend, it suggests that there might be several areas needing improvement to retain more employees, such as better workplace culture, career development opportunities, or benefits packages.
#
# ...

# %%
prompt = f"""
You are a Workforce Analytics AI Assistant.

Analyze ONLY the following calculated workforce data.
Do NOT invent facts or assume reasons that are not present in the data.

DATA:
Total employees: {len(df)}
Average age: {df["Age"].mean():.2f}
Average salary: {df["Salary"].mean():.2f}
Attrition rate: {df["Attrition"].mean() * 100:.2f}%
Average engagement: {df["Engagement_Score"].mean():.2f}
Average job satisfaction: {df["Job_Satisfaction"].mean():.2f}

Department counts:
{df["Department"].value_counts().to_dict()}

Provide:
1. Workforce overview
2. Key findings
3. Attrition observation
4. Two HR recommendations

If the data does not explain WHY something is happening,
clearly say that the available data is insufficient to determine the cause.
"""

messages = [
    {
        "role": "user",
        "content": prompt
    }
]

result = pipe(messages, max_new_tokens=250)

print(result[0]["generated_text"][-1]["content"])
# Out:
# [transformers] Both `max_new_tokens` (=250) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ### 1. Workforce Overview
#
# **Total Employees:**
# - **Count:** 1000
# - **Age Range:** The average age of 40.66 years suggests an older workforce with some variability within this range (e.g., from early 40s to late 40s).
#
# **Salary Information:**
# - **Average Salary:** $96,817.11
# - This indicates a significant portion of the workforce earns above the national median wage for their location and industry, suggesting high-paying roles exist.
#
# **Engagement & Job Satisfaction:**
# - **Average Engagement:** 2.53
# - **Average Job Satisfaction:** 2.50
# - These values suggest moderate levels of engagement and satisfaction across departments, indicating overall positive work environments but room for improvement.
#
# ...

# %%
display(df.head(10))
# Out:
#    Employee_ID  Age  Gender   Department    Job_Role    Education  Experience  \
# 0            1   25    Male  Engineering  Specialist      Masters          10
# 1            2   28    Male   Operations  Specialist    Bachelors          21
# 2            3   27  Female  Engineering  Specialist    Bachelors           2
# 3            4   42    Male  Engineering    Engineer    Bachelors          29
# 4            5   28  Female  Engineering     Analyst      Masters          13
# 5            6   25  Female           HR     Analyst          PhD           2
# 6            7   49    Male        Sales     Analyst  High School          21
# 7            8   24  Female           HR     Analyst    Bachelors           4
# 8            9   23    Male           HR     Manager    Bachelors          10
# 9           10   23  Female      Finance  Specialist      Masters          25
#
#    Salary  Performance_Score  Job_Satisfaction  Work_Life_Balance  \
# ...

# %%
def ask_workforce_ai(question):

    context = f"""
    Workforce Dataset:
    Total employees: {len(df)}
    Average age: {df["Age"].mean():.2f}
    Average salary: {df["Salary"].mean():.2f}
    Attrition rate: {df["Attrition"].mean() * 100:.2f}%
    Average engagement: {df["Engagement_Score"].mean():.2f}
    Average job satisfaction: {df["Job_Satisfaction"].mean():.2f}

    Department employee counts:
    {df["Department"].value_counts().to_dict()}
    """

    prompt = f"""
    You are a Workforce Analytics AI Assistant.

    Answer the user's question using ONLY the workforce data provided below.

    Do not invent facts, external statistics, causes, or assumptions.
    If the provided data cannot answer the question, say:
    "The available data is insufficient to answer this question."

    {context}

    User Question:
    {question}

    Give a short, clear answer.
    """

    messages = [
        {
            "role": "user",
            "content": prompt
        }
    ]

    result = pipe(messages, max_new_tokens=150)

    return result[0]["generated_text"][-1]["content"]

# %%
answer = ask_workforce_ai(
    "What is the attrition rate in this organization?"
)

print(answer)
# Out:
# [transformers] Both `max_new_tokens` (=150) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The attrition rate in this organization is 15.90%.

# %%
print(ask_workforce_ai(
    "Which department has the most employees?"
))
# Out:
# [transformers] Both `max_new_tokens` (=150) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Based on the information provided in the dataset, the Marketing department has the most employees with 194 employees.

# %% [markdown]
# ### Display the dataset shape

# %%
print(df.shape)
# Out:
# (5063, 1)

# %%
print(f"Dataset shape: {df.shape}")
# Out:
# Dataset shape: (5063, 1)

# %%
print(f"Dataset shape: {df.shape}")
# Out:
# Dataset shape: (5063, 1)

# %%
print(df.columns.tolist())
# Out:
# ['{']

# %%
print(df.head())
# Out:
#                         {
# "nbformat": 4         NaN
# "nbformat_minor": 0   NaN
# "metadata": {         NaN
#   "colab": {          NaN
#     "provenance": []  NaN

# %%
print(df.columns)
# Out:
# Index(['{'], dtype='object')

# %% [markdown]
# ### Display basic statistics

# %%
display(df.describe(include='all'))
# Out:
#         Employee_ID         Age Gender   Department    Job_Role  Education  \
# count    500.000000  500.000000    500          500         500        500
# unique          NaN         NaN      3            6           5          4
# top             NaN         NaN   Male  Engineering  Specialist  Bachelors
# freq            NaN         NaN    253           96         110        250
# mean     250.500000   41.160000    NaN          NaN         NaN        NaN
# std      144.481833   10.933136    NaN          NaN         NaN        NaN
# min        1.000000   22.000000    NaN          NaN         NaN        NaN
# 25%      125.750000   31.000000    NaN          NaN         NaN        NaN
# 50%      250.500000   42.000000    NaN          NaN         NaN        NaN
# 75%      375.250000   50.000000    NaN          NaN         NaN        NaN
# max      500.000000   59.000000    NaN          NaN         NaN        NaN
#
# ...

# %% [markdown]
# ### Check for missing values

# %%
display(df.isnull().sum())
# Out:
# Employee_ID           0
# Age                   0
# Gender                0
# Department            0
# Job_Role              0
# Education             0
# Experience            0
# Salary                0
# Performance_Score     0
# Job_Satisfaction      0
# Work_Life_Balance     0
# Training_Hours        0
# Skills                0
# Years_at_Company      0
# Attendance            0
# Engagement_Score      0
# Attrition             0
# Recruitment_Source    0
# dtype: int64

# %% [markdown]
# ### Cell 3: Data Cleaning and Preprocessing

# %%
# Display current data types
print("Original Data Types:")
display(df.dtypes)

# Convert 'Skills' list to a comma-separated string
df['Skills'] = df['Skills'].apply(lambda x: ', '.join(x))

# Convert suitable categorical columns to 'category' dtype for memory efficiency
# and explicit type handling, including the newly added ones.
for col in ['Gender', 'Department', 'Job_Role', 'Education', 'Recruitment_Source', 'Diversity_Category', 'Skill_Level']:
    df[col] = df[col].astype('category')

# Display data types after preprocessing
print("\nData Types After Preprocessing:")
display(df.dtypes)

# Display the first few rows to show changes in 'Skills' column
print("\nFirst 5 rows after preprocessing 'Skills' column and converting data types:")
display(df.head())
# Out:
# Original Data Types:
# Employee_ID            int64
# Age                    int64
# Gender                object
# Department            object
# Job_Role              object
# Education             object
# Experience             int64
# Salary                 int64
# Performance_Score      int64
# Job_Satisfaction       int64
# Work_Life_Balance      int64
# Training_Hours         int64
# Skills                object
# Years_at_Company       int64
# Attendance             int64
# Engagement_Score       int64
# Attrition              int64
# Recruitment_Source    object
# Diversity_Category    object
# Skill_Level           object
# dtype: object
# Data Types After Preprocessing:
# Employee_ID              int64
# Age                      int64
# Gender                category
# Department            category
# Job_Role              category
# Education             category
# Experience               int64
# Salary                   int64
# Performance_Score        int64
# ...

# %% [markdown]
# ### Continued Data Cleaning: Duplicates and Final Checks

# %%
# Check for duplicate Employee_ID's
duplicate_employees = df[df.duplicated(subset=['Employee_ID'], keep=False)]

if not duplicate_employees.empty:
    print("Duplicate Employee_ID's found:")
    display(duplicate_employees)
    # Assuming Employee_ID should be unique, remove duplicates if any
    df.drop_duplicates(subset=['Employee_ID'], inplace=True)
    print("Duplicate Employee_ID's removed. New DataFrame shape:", df.shape)
else:
    print("No duplicate Employee_ID's found.")

# Re-check for any missing values after potential duplicate removal
print("\nMissing values after duplicate check:")
display(df.isnull().sum())
# Out:
# No duplicate Employee_ID's found.
#
# Missing values after duplicate check:
# Employee_ID           0
# Age                   0
# Gender                0
# Department            0
# Job_Role              0
# Education             0
# Experience            0
# Salary                0
# Performance_Score     0
# Job_Satisfaction      0
# Work_Life_Balance     0
# Training_Hours        0
# Skills                0
# Years_at_Company      0
# Attendance            0
# Engagement_Score      0
# Attrition             0
# Recruitment_Source    0
# dtype: int64

# %% [markdown]
# ### Basic Workforce Analytics with Plotly

# %%
import plotly.express as px

# 1. Employee count by Department
department_counts = df['Department'].value_counts().reset_index()
department_counts.columns = ['Department', 'Employee Count']
fig_dept = px.bar(department_counts, x='Department', y='Employee Count',
                  title='Employee Count by Department', template='plotly_white')
fig_dept.show()

print("\nSummary: Employee Count by Department")
display(department_counts)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 2. Employee count by Job Role
job_role_counts = df['Job_Role'].value_counts().reset_index()
job_role_counts.columns = ['Job Role', 'Employee Count']
fig_job = px.bar(job_role_counts, x='Job Role', y='Employee Count',
                 title='Employee Count by Job Role', template='plotly_white')
fig_job.show()

print("\nSummary: Employee Count by Job Role")
display(job_role_counts)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 3. Gender distribution
gender_dist = df['Gender'].value_counts().reset_index()
gender_dist.columns = ['Gender', 'Count']
fig_gender = px.pie(gender_dist, names='Gender', values='Count',
                    title='Gender Distribution', template='plotly_white')
fig_gender.show()

print("\nSummary: Gender Distribution")
display(gender_dist)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 4. Age distribution
fig_age = px.histogram(df, x='Age', nbins=10, title='Age Distribution',
                       template='plotly_white')
fig_age.show()

print("\nSummary: Age Distribution")
display(df['Age'].describe())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 5. Salary distribution
fig_salary = px.histogram(df, x='Salary', nbins=20, title='Salary Distribution',
                          template='plotly_white')
fig_salary.show()

print("\nSummary: Salary Distribution")
display(df['Salary'].describe())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 6. Experience distribution
fig_exp = px.histogram(df, x='Experience', nbins=15, title='Experience Distribution (Years)',
                       template='plotly_white')
fig_exp.show()

print("\nSummary: Experience Distribution")
display(df['Experience'].describe())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 7. Performance Score distribution
performance_dist = df['Performance_Score'].value_counts().sort_index().reset_index()
performance_dist.columns = ['Performance Score', 'Count']
fig_perf = px.bar(performance_dist, x='Performance Score', y='Count',
                  title='Performance Score Distribution', template='plotly_white')
fig_perf.show()

print("\nSummary: Performance Score Distribution")
display(performance_dist)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 8. Engagement Score distribution
engagement_dist = df['Engagement_Score'].value_counts().sort_index().reset_index()
engagement_dist.columns = ['Engagement Score', 'Count']
fig_eng = px.bar(engagement_dist, x='Engagement Score', y='Count',
                 title='Engagement Score Distribution', template='plotly_white')
fig_eng.show()

print("\nSummary: Engagement Score Distribution")
display(engagement_dist)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Cell 4: Exploratory Data Analysis (EDA)

# %%
import plotly.express as px

print("### Exploring Relationships with Attrition")

# Attrition by Department
at_dept = df.groupby('Department')['Attrition'].value_counts(normalize=True).unstack().fillna(0)
at_dept['Attrition Rate'] = at_dept.get(1, 0) * 100 # Assuming 1 is 'Yes' for Attrition
fig_at_dept = px.bar(at_dept.sort_values('Attrition Rate', ascending=False).reset_index(),
                     x='Department', y='Attrition Rate', title='Attrition Rate by Department',
                     template='plotly_white')
fig_at_dept.show()
print("\nSummary: Attrition Rate by Department")
display(at_dept[['Attrition Rate']].sort_values('Attrition Rate', ascending=False))

# Attrition by Job Role
at_job = df.groupby('Job_Role')['Attrition'].value_counts(normalize=True).unstack().fillna(0)
at_job['Attrition Rate'] = at_job.get(1, 0) * 100
fig_at_job = px.bar(at_job.sort_values('Attrition Rate', ascending=False).reset_index(),
                    x='Job_Role', y='Attrition Rate', title='Attrition Rate by Job Role',
                    template='plotly_white')
fig_at_job.show()
print("\nSummary: Attrition Rate by Job Role")
display(at_job[['Attrition Rate']].sort_values('Attrition Rate', ascending=False))

# Attrition by Gender
at_gender = df.groupby('Gender')['Attrition'].value_counts(normalize=True).unstack().fillna(0)
at_gender['Attrition Rate'] = at_gender.get(1, 0) * 100
fig_at_gender = px.bar(at_gender.sort_values('Attrition Rate', ascending=False).reset_index(),
                       x='Gender', y='Attrition Rate', title='Attrition Rate by Gender',
                       template='plotly_white')
fig_at_gender.show()
print("\nSummary: Attrition Rate by Gender")
display(at_gender[['Attrition Rate']].sort_values('Attrition Rate', ascending=False))
# Out:
# ### Exploring Relationships with Attrition
# /tmp/ipykernel_1748/3701076862.py:6: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Cell 5: Attrition Prediction Model - Data Preparation

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Make a copy of the DataFrame to avoid modifying the original during encoding
df_model = df.copy()

# Separate target variable (Attrition)
X = df_model.drop('Attrition', axis=1)
y = df_model['Attrition']

# Explicitly drop 'Employee_ID' and 'Skills' column from X as they are not suitable for direct model input.
# Check if columns exist before dropping to prevent errors.
if 'Employee_ID' in X.columns:
    X = X.drop(columns=['Employee_ID'])
if 'Skills' in X.columns:
    X = X.drop(columns=['Skills'])

# Safeguard: ensure no other non-numeric 'object' type columns remain that weren't explicitly handled
# After properly converting intended categorical features to 'category' dtype, this should ideally be empty.
object_columns_to_drop = X.select_dtypes(include='object').columns
if len(object_columns_to_drop) > 0:
    print(f"Warning: Dropping unhandled 'object' type columns: {list(object_columns_to_drop)}")
    X = X.drop(columns=object_columns_to_drop)

# Identify categorical and numerical features
categorical_features = X.select_dtypes(include='category').columns
numerical_features = X.select_dtypes(include=np.number).columns

# Apply One-Hot Encoding to categorical features
X = pd.get_dummies(X, columns=categorical_features, drop_first=True)

# Scale numerical features (important for many ML models)
# Initialize StandardScaler
scaler = StandardScaler()

# Fit and transform the numerical features
X[numerical_features] = scaler.fit_transform(X[numerical_features])

print("Features after encoding and scaling:")
display(X.head())
print("Target variable (Attrition):")
display(y.head())
# Out:
# Features after encoding and scaling:
#         Age  Experience    Salary  Performance_Score  Job_Satisfaction  \
# 0  0.898325    1.336688 -1.657730          -1.317837          1.359994
# 1 -0.933869   -1.317302  0.708317           0.502380          1.359994
# 2  1.081544   -0.509566 -1.107662           1.412488         -1.402350
# 3 -0.659040   -0.048003  1.201573          -0.407729          0.439213
# 4  0.348666    0.182779  1.208678          -1.317837         -0.481568
#
#    Work_Life_Balance  Training_Hours  Years_at_Company  Attendance  \
# 0          -1.352635       -1.273000          1.614001    0.884155
# 1           1.343647       -1.234427         -0.264333    0.194666
# 2          -0.453874       -1.697308         -1.459636   -0.035164
# 3          -0.453874        0.848538         -0.093575   -0.724654
# 4           0.444887       -0.038651         -0.605848   -1.414143
#
#    Engagement_Score  ...  Job_Role_Specialist  Education_High School  \
# ...

# %% [markdown]
# ### Split Data into Training and Testing Sets

# %%
from sklearn.model_selection import train_test_split

# Split the dataset into training and testing sets
# We'll use a 70/30 split, which is common for machine learning tasks
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")

print("\nClass distribution in training set:")
display(y_train.value_counts(normalize=True))
print("\nClass distribution in testing set:")
display(y_test.value_counts(normalize=True))
# Out:
# X_train shape: (700, 30)
# X_test shape: (300, 30)
# y_train shape: (700,)
# y_test shape: (300,)
#
# Class distribution in training set:
# Attrition
# 0    0.848571
# 1    0.151429
# Name: proportion, dtype: float64
# Class distribution in testing set:
# Attrition
# 0    0.846667
# 1    0.153333
# Name: proportion, dtype: float64

# %% [markdown]
# ### Attrition Prediction Model Training & Evaluation

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix

# Initialize and train the Logistic Regression model
model = LogisticRegression(random_state=42, solver='liblinear') # 'liblinear' solver works well for small datasets and binary classification
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)
y_pred_proba = model.predict_proba(X_test)[:, 1] # Probability of attrition

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred_proba)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
print(f"ROC AUC Score: {roc_auc:.4f}")

print("\nConfusion Matrix:")
display(pd.DataFrame(confusion_matrix(y_test, y_pred),
                   index=['Actual No Attrition', 'Actual Attrition'],
                   columns=['Predicted No Attrition', 'Predicted Attrition']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1748/3423618787.py in <cell line: 0>()
#       4 # Initialize and train the Logistic Regression model
#       5 model = LogisticRegression(random_state=42, solver='liblinear') # 'liblinear' solver works well for small datasets and binary classification
# ----> 6 model.fit(X_train, y_train)
#       7
#       8 # Make predictions on the test set
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1220             _dtype = [np.float64, np.float32]
#    1221
# ...

# %% [markdown]
# ### Feature Importance and High-Risk Employees

# %%
# Get feature importance (coefficients for Logistic Regression)
feature_importance = pd.DataFrame({
    'Feature': X.columns,
    'Coefficient': model.coef_[0]
}).sort_values(by='Coefficient', ascending=False)

print("Top 10 most influential features (positive coefficients indicate higher attrition risk):")
display(feature_importance.head(10))

print("\nTop 10 most influential features (negative coefficients indicate lower attrition risk):")
display(feature_importance.tail(10))

# Displaying high-risk employee categories (example: employees with highest predicted attrition probability)
high_risk_employees = X_test.copy()
high_risk_employees['Predicted_Attrition_Probability'] = y_pred_proba
high_risk_employees['Actual_Attrition'] = y_test

print("\nEmployees with highest predicted attrition probability:")
display(high_risk_employees.sort_values(by='Predicted_Attrition_Probability', ascending=False).head())

# %% [markdown]
# ### Attrition Prediction Model Training & Evaluation

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix

# Initialize and train the Logistic Regression model with class_weight='balanced'
model = LogisticRegression(random_state=42, solver='liblinear', class_weight='balanced')
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)
y_pred_proba = model.predict_proba(X_test)[:, 1] # Probability of attrition

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred_proba)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
print(f"ROC AUC Score: {roc_auc:.4f}")

print("\nConfusion Matrix:")
display(pd.DataFrame(confusion_matrix(y_test, y_pred),
                   index=['Actual No Attrition', 'Actual Attrition'],
                   columns=['Predicted No Attrition', 'Predicted Attrition']))
# Out:
# Accuracy: 0.5300
# Precision: 0.1429
# Recall: 0.4130
# F1-Score: 0.2123
# ROC AUC Score: 0.4977
#
# Confusion Matrix:
#                      Predicted No Attrition  Predicted Attrition
# Actual No Attrition                     140                  114
# Actual Attrition                         27                   19

# %% [markdown]
# ### Feature Importance and High-Risk Employees

# %%
# Get feature importance (coefficients for Logistic Regression)
feature_importance = pd.DataFrame({
    'Feature': X.columns,
    'Coefficient': model.coef_[0]
}).sort_values(by='Coefficient', ascending=False)

print("Top 10 most influential features (positive coefficients indicate higher attrition risk):")
display(feature_importance.head(10))

print("\nTop 10 most influential features (negative coefficients indicate lower attrition risk):")
display(feature_importance.tail(10))

# Displaying high-risk employee categories (example: employees with highest predicted attrition probability)
high_risk_employees = X_test.copy()
high_risk_employees['Predicted_Attrition_Probability'] = y_pred_proba
high_risk_employees['Actual_Attrition'] = y_test

print("\nEmployees with highest predicted attrition probability:")
display(high_risk_employees.sort_values(by='Predicted_Attrition_Probability', ascending=False).head())
# Out:
# Top 10 most influential features (positive coefficients indicate higher attrition risk):
#                         Feature  Coefficient
# 24  Recruitment_Source_LinkedIn     0.330997
# 29     Skill_Level_Intermediate     0.273898
# 15        Department_Operations     0.220280
# 25  Recruitment_Source_Referral     0.217789
# 26   Recruitment_Source_Website     0.158780
# 4              Job_Satisfaction     0.156601
# 14         Department_Marketing     0.121622
# 16             Department_Sales     0.111320
# 3             Performance_Score     0.077634
# 8                    Attendance     0.060102
# Top 10 most influential features (negative coefficients indicate lower attrition risk):
#                 Feature  Coefficient
# 11         Gender_Other    -0.047785
# 0                   Age    -0.097023
# 19     Job_Role_Manager    -0.097225
# 13        Department_HR    -0.120776
# 6        Training_Hours    -0.153172
# 17    Job_Role_Director    -0.313298
# ...

# %% [markdown]
# ## Cell 6: Workforce KPI Analysis and Interactive Visualizations

# %% [markdown]
# ### Executive Overview KPIs

# %%
import pandas as pd
import numpy as np

# 1. Total Employees
total_employees = len(df)

# 2. Attrition Rate
attrition_rate = (df['Attrition'].sum() / total_employees) * 100

# 3. Average Salary
average_salary = df['Salary'].mean()

# 4. Average Performance Score
average_performance = df['Performance_Score'].mean()

# 5. Average Engagement Score
average_engagement = df['Engagement_Score'].mean()

# 6. Training Participation (assuming participation is recorded by Training_Hours > 0)
training_participation = (df[df['Training_Hours'] > 0].shape[0] / total_employees) * 100

# Display KPIs
print("### Workforce Executive Overview KPIs:")
print(f"- Total Employees: {total_employees}")
print(f"- Attrition Rate: {attrition_rate:.2f}%")
print(f"- Average Salary: ${average_salary:,.2f}")
print(f"- Average Performance Score: {average_performance:.2f}")
print(f"- Average Engagement Score: {average_engagement:.2f}")
print(f"- Training Participation Rate: {training_participation:.2f}%")
# Out:
# ### Workforce Executive Overview KPIs:
# - Total Employees: 1000
# - Attrition Rate: 15.20%
# - Average Salary: $96,282.41
# - Average Performance Score: 2.45
# - Average Engagement Score: 2.45
# - Training Participation Rate: 100.00%

# %% [markdown]
# ### Department-wise Employee Count

# %%
import plotly.express as px

# Department-wise Employee Count (re-using from EDA for completeness in KPI section)
department_counts = df['Department'].value_counts().reset_index()
department_counts.columns = ['Department', 'Employee Count']
fig_dept_kpi = px.bar(department_counts, x='Department', y='Employee Count',
                      title='Employee Count by Department', template='plotly_white')
fig_dept_kpi.show()

print("\nSummary: Employee Count by Department")
display(department_counts)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Gender Diversity Analysis

# %%
# Gender Distribution (re-using from EDA for completeness in KPI section)
gender_dist = df['Gender'].value_counts(normalize=True).reset_index()
gender_dist.columns = ['Gender', 'Proportion']
fig_gender_kpi = px.pie(gender_dist, names='Gender', values='Proportion',
                        title='Gender Distribution', template='plotly_white')
fig_gender_kpi.show()

print("\nSummary: Gender Distribution")
display(gender_dist)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Performance Analysis

# %%
# Performance Score Distribution (re-using from EDA for completeness in KPI section)
performance_dist = df['Performance_Score'].value_counts().sort_index().reset_index()
performance_dist.columns = ['Performance Score', 'Count']
fig_perf_kpi = px.bar(performance_dist, x='Performance Score', y='Count',
                      title='Performance Score Distribution', template='plotly_white')
fig_perf_kpi.show()

print("\nSummary: Performance Score Distribution")
display(performance_dist)

# Performance by Department
perf_by_dept = df.groupby('Department')['Performance_Score'].mean().reset_index()
fig_perf_dept = px.bar(perf_by_dept.sort_values('Performance_Score', ascending=False),
                       x='Department', y='Performance_Score',
                       title='Average Performance Score by Department', template='plotly_white')
fig_perf_dept.show()
print("\nSummary: Average Performance Score by Department")
display(perf_by_dept.sort_values('Performance_Score', ascending=False))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Skill Gap Analysis

# %%
# Analyze most common skills
from collections import Counter
import itertools

# Assuming 'Skills' column is a string of comma-separated skills
df['Skills_List'] = df['Skills'].apply(lambda x: [skill.strip() for skill in x.split(',')])
all_skills = list(itertools.chain.from_iterable(df['Skills_List']))
skill_counts = Counter(all_skills)

skill_df = pd.DataFrame(skill_counts.items(), columns=['Skill', 'Count']).sort_values(by='Count', ascending=False)
fig_skills = px.bar(skill_df.head(10), x='Skill', y='Count', title='Top 10 Most Common Skills', template='plotly_white')
fig_skills.show()

print("\nSummary: Top 10 Most Common Skills")
display(skill_df.head(10))

# Example of a simple skill gap analysis: identify skills that are less common but might be in demand
# (This would ideally be informed by external data on industry demand, but for prototype, we can show less common skills)
print("\nLess common skills (potential skill gaps if in demand):")
display(skill_df.tail(10))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Cell 7: Employee Engagement Analysis

# %% [markdown]
# ### Job Satisfaction, Engagement Score, and Work-Life Balance Distributions

# %%
import plotly.express as px

# 1. Job Satisfaction Distribution
fig_satisfaction = px.histogram(df, x='Job_Satisfaction', title='Job Satisfaction Distribution', template='plotly_white')
fig_satisfaction.show()
print("\nSummary: Job Satisfaction Distribution")
display(df['Job_Satisfaction'].value_counts().sort_index())

# 2. Work-Life Balance Distribution
fig_wlb = px.histogram(df, x='Work_Life_Balance', title='Work-Life Balance Distribution', template='plotly_white')
fig_wlb.show()
print("\nSummary: Work-Life Balance Distribution")
display(df['Work_Life_Balance'].value_counts().sort_index())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Training Participation Analysis

# %%
# Training Hours Distribution
fig_training = px.histogram(df, x='Training_Hours', nbins=20, title='Training Hours Distribution', template='plotly_white')
fig_training.show()
print("\nSummary: Training Hours Distribution")
display(df['Training_Hours'].describe())

# Training Participation Rate was already calculated in Executive Overview KPIs, but we can visualize it here too.
training_participation_data = df['Training_Hours'].apply(lambda x: 'Participated' if x > 0 else 'No Participation').value_counts().reset_index()
training_participation_data.columns = ['Participation', 'Count']
fig_training_pie = px.pie(training_participation_data, names='Participation', values='Count',
                          title='Training Participation Overview', template='plotly_white')
fig_training_pie.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Relationship between Engagement, Performance, and Attrition

# %%
# Engagement Score vs Performance Score
fig_eng_perf_rel = px.box(df, x='Engagement_Score', y='Performance_Score',
                          title='Performance Score by Engagement Score', template='plotly_white', points='all')
fig_eng_perf_rel.show()

# Job Satisfaction vs Attrition
at_satisfaction = df.groupby('Job_Satisfaction')['Attrition'].value_counts(normalize=True).unstack().fillna(0)
at_satisfaction['Attrition Rate'] = at_satisfaction.get(1, 0) * 100
fig_at_satisfaction = px.bar(at_satisfaction.sort_values('Attrition Rate', ascending=False).reset_index(),
                             x='Job_Satisfaction', y='Attrition Rate', title='Attrition Rate by Job Satisfaction',
                             template='plotly_white')
fig_at_satisfaction.show()
print("\nSummary: Attrition Rate by Job Satisfaction")
display(at_satisfaction[['Attrition Rate']].sort_values('Attrition Rate', ascending=False))

# Work-Life Balance vs Attrition
at_wlb = df.groupby('Work_Life_Balance')['Attrition'].value_counts(normalize=True).unstack().fillna(0)
at_wlb['Attrition Rate'] = at_wlb.get(1, 0) * 100
fig_at_wlb = px.bar(at_wlb.sort_values('Attrition Rate', ascending=False).reset_index(),
                    x='Work_Life_Balance', y='Attrition Rate', title='Attrition Rate by Work-Life Balance',
                    template='plotly_white')
fig_at_wlb.show()
print("\nSummary: Attrition Rate by Work-Life Balance")
display(at_wlb[['Attrition Rate']].sort_values('Attrition Rate', ascending=False))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# !pip install -q openai

# %%
import openai

print("OpenAI library installed successfully!")
# Out:
# OpenAI library installed successfully!

# %%
from google.colab import userdata
from openai import OpenAI

api_key = userdata.get("OPENAI_API_KEY")

client = OpenAI(api_key=api_key)

print("API connection setup successful!")
# Out:
# API connection setup successful!

# %%
import torch

print("GPU available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# GPU available: False
# GPU: No GPU

# %%
# !pip install -q -U transformers accelerate
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 31.4 MB/s eta 0:00:00

# %%
import torch

print("GPU available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
else:
    print("No GPU")
# Out:
# GPU available: False
# No GPU

# %%
import torch

print("GPU available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
else:
    print("No GPU")
# Out:
# GPU available: True
# GPU: Tesla T4

# %%
# !pip install -q -U transformers accelerate
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 90.3 MB/s eta 0:00:00

# %%
# !pip install -q -U transformers accelerate

# %%
import transformers
import accelerate

print("Transformers version:", transformers.__version__)
print("Accelerate installed successfully!")
# Out:
# Transformers version: 5.15.1
# Accelerate installed successfully!

# %%
from transformers import pipeline

pipe = pipeline(
    "text-generation",
    model="Qwen/Qwen2.5-1.5B-Instruct",
    device=0
)

print("Local LLM loaded successfully!")
# Out:
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors: reconstructing file:   0%|          |  0.00B / 3.09GB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# Local LLM loaded successfully!

# %%
messages = [
    {
        "role": "user",
        "content": "Explain employee attrition in simple terms."
    }
]

result = pipe(messages, max_new_tokens=150)

print(result[0]["generated_text"][-1]["content"])
# Out:
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=150) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer Qwen2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# ...

# %%
print(df.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_548/1361441755.py in <cell line: 0>()
# ----> 1 print(df.columns.tolist())
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv("something.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_548/2321582474.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("something.csv")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-0f3f7a79-2f6f-4688-9ea3-0f04c6212488" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0f3f7a79-2f6f-4688-9ea3-0f04c6212488">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files

print("Pandas is ready.")
# Out:
# Pandas is ready.

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fef74013-3e8d-46fb-8397-f420a14aefe4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fef74013-3e8d-46fb-8397-f420a14aefe4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-d2a0ca2d-32b6-4ba0-b14c-6694a245f134" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d2a0ca2d-32b6-4ba0-b14c-6694a245f134">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(uploaded.keys())
# Out:
# dict_keys(['Untitled0 (2).ipynb'])

# %%
filename = next(iter(uploaded))
print(filename)
# Out:
# Untitled0 (2).ipynb

# %%
import pandas as pd

df = pd.read_csv(filename, on_bad_lines='skip')

print("Dataset loaded successfully!")
print("Dataset shape:", df.shape)
# Out:
# Dataset loaded successfully!
# Dataset shape: (5063, 1)

# %%
print(df.shape)
# Out:
# (5063, 1)

# %%
df = pd.read_csv(filename, on_bad_lines='skip')
print("Shape:", df.shape)
# Out:
# Shape: (5063, 1)

# %%
print(filename)
# Out:
# Untitled0 (2).ipynb

# %%
print(ask_workforce_ai(
    "What is the average salary?"
))
# Out:
# [transformers] Both `max_new_tokens` (=150) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The average salary for the entire workforce is $96,817.11.
